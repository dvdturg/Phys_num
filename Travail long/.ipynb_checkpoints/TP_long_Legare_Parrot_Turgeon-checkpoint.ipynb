# %% [markdown]
# <h1><center>Physique numérique (PHY-3500)</center></h1>
# <h1><center>Projet - Propagation d'un faisceau lumineux dans un milieu inhomogène</center></h1>

# %% [markdown]
# ## Nom des membres de l'équipe:
#
# ### Légaré, Ophélie : 111 182 608
# ### Parrot, Anaïs : 111 184 980
# ### Turgeon, David : 111 182 265

# %% [markdown]
# ### Importation des modules :

# %%
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter
import matplotlib.ticker as ticker

# %% [markdown]
# # Split-Step Beam propagation method

# %% [markdown]
# La méthode et les exemples s'inspirent de Poon et Kim, *Engineering Optics with MATLAB* (World Scientific, 2006).
# https://refractiveindex.info/?shelf=main&book=Cu&page=Johnson, document consulté le 2 avril 2021.

# %% [markdown]
# ## Utilisation du Split-Step Beam propagation method pour la propagation d'un faisceau gaussien au travers une lentille
#
# Simulation de la propagation d'un faisceau gaussien d'une longueur d'onde centrale de 0.663$\mu$m, d'une largeur de 10mm à travers une lentille de longueur focale de 16m sur une distance de 40m avec des incréments à tout les 1m.

# %%
"""Gaussian Beam"""
N = 255# Sampling number  
L = 50e-3 # Display area
Ld = 0.663e-6 # Wavelength
k0 = 2*np.pi/Ld # Wave number
w0 = 10e-3 # Initial beam waist
dz = 1000e-3 # deltaz
Z = 40 # final z position
f = 16000e-3 # Focal length of lens

# %%
dx = L/N # Step size
# Définir les vecteurs x, y, kx et ky (les nombres d'onde dans ces directions) :
x = np.zeros(N+1)
Kx = np.zeros(N+1)
y = np.zeros(N+1)
Ky = np.zeros(N+1)
for m in range(N+1):
    x[m] = (m)*dx-L/2
    Kx[m] = (2*np.pi*(m))/(N*dx)-((2*np.pi*(N-1))/(N*dx))/2
for n in range(N+1):
    y[n] = (n)*dx-L/2
    Ky[n] = (2*np.pi*(n))/(N*dx)-((2*np.pi*(N-1))/(N*dx))/2
    
X,Y = np.meshgrid(x,y)
KX,KY = np.meshgrid(Kx,Ky)

Gau_ini = (1/(w0*np.pi**0.5))*np.exp(-(X**2+Y**2)/(w0**2)) # Gaussian beam in space domain

Energy_init = dx*dx*sum(sum(abs(Gau_ini)**2)) # Energy of initial gaussian beam

Lens = np.exp(1j*k0/(2*f)*(X**2+Y**2)) # Lens eaquation

Gau_ini = Gau_ini*Lens # Gaussian beam through the lens

H = np.exp(1j/(2*k0)*dz*(KX**2+KY**2)) # Free space transfer function of propagation

Gau = Gau_ini
nl = 0
z = np.arange(0,Z+dz,dz)
Gau_pro = np.zeros((N+1,len(z)),dtype = complex)
for i in z:  # Calculer la propagation du faisceau :
    FGau = np.fft.fft2(Gau)
    FGau = FGau*np.fft.fftshift(H)
    Gau = np.fft.ifft2(FGau)
    Gau_pro[:,nl] = Gau[:,int(N/2)]
    nl += 1

Energy_pro = dx*dx*sum(sum(abs(Gau)**2)) # Vérifier la conservation de l'énergie

x *= 1e3
y *= 1e3
z *= 1e3

# %%
plt.rcParams['figure.dpi'] = 150  



fig = plt.figure()
ax = fig.gca(projection='3d')
surf = ax.plot_surface(X, Y, abs(Gau_ini), cmap=cm.jet, linewidth=0, antialiased=False)


ax.set_xlabel("x (mm)")
ax.set_ylabel('y (mm)')
ax.set_title("Initial Gaussian beam profile")
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))
plt.show()


fig = plt.figure()
ax = fig.gca(projection='3d')
surf = ax.plot_surface(X, Y, abs(Gau), cmap=cm.jet,
                       linewidth=0, antialiased=False)
ax.set_xlabel("x (mm)")
ax.set_ylabel('y (mm)')
ax.set_title("Propagated Gaussian Beam at Z")
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))
plt.show()


fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
for i in range(nl):
    ax.plot(z[i]*np.ones(len(x)),  abs(Gau_pro[:,i]) ,x, zdir='y')
ax.set_xlabel('z (mm)')
ax.set_ylabel('x (mm)')
ax.set_title("Beam profile along z")
plt.show()



fig,ax = plt.subplots()
A = np.zeros(nl)
for i in range(nl):
    A[i] = 1/max(abs(Gau_pro[:,i]))
B = np.diag(A)
N_Gau_pro = np.dot(abs(Gau_pro),B)
im = ax.contourf(z,x,N_Gau_pro,np.linspace(0,np.amax(abs(N_Gau_pro)),N),cmap = "jet")
ax.set_xlabel("z (mm)")
ax.set_ylabel("x (mm)")
ax.set_title("Beam waist along z")
fig.colorbar(im, ax=ax)
plt.show()


fig, ax = plt.subplots()
for i in range(nl):
    A[i] = max(abs(Gau_pro[:,i]))
ax.plot(z, A/max(A))
ax.set_xlabel("z (mm)")
ax.set_ylabel("Amplitude normalisée [-]")
ax.set_title("Peak amplitude along z")
plt.show()

# %% [markdown]
# ## Diffraction pattern from a circular hole
#
# Simulation de la diffraction d'un front d'onde plan passant au travers d'une fente circulaire de 0.02mm de diamètre. La longueur d'onde centrale est de 0.663$\mu$m et la longueur focale de la lentille est posée à 1e20 mm pour s'assurer qu'elle ait un impact négligeable sur la propagation du faisceau. La simulation est faite sur une distance de 15m avec des incréments à tout les 1m.

# %%
N = 255# Sampling number 
L = 30e-3 # Display area
Ld = 0.663e-6 # Wavelength
k0 = 2*np.pi/Ld # Wave number
w0 = 10e-3 # Initial beam waist
dz = 1000e-3 # deltaz
Z = 15 # final z position
f = 1e20 # Focal length of lens

# %%
dx = L/N # Step size
# Définir les vecteurs x, y, kx et ky (les nombres d'onde dans ces directions) :
x = np.zeros(N+1)
Kx = np.zeros(N+1)
y = np.zeros(N+1)
Ky = np.zeros(N+1)
for m in range(N+1):
    x[m] = (m)*dx-L/2
    Kx[m] = (2*np.pi*(m))/(N*dx)-((2*np.pi*(N-1))/(N*dx))/2
for n in range(N+1):
    y[n] = (n)*dx-L/2
    Ky[n] = (2*np.pi*(n))/(N*dx)-((2*np.pi*(N-1))/(N*dx))/2
    
X,Y = np.meshgrid(x,y)
KX,KY = np.meshgrid(Kx,Ky)
Gau_ini = np.zeros((len(X),len(Y)))
for i in range(len(X)): # Définir le faisceau comme passant dans une fente :
    for j in range(len(Y)):
        if ( X[j][i]**2+Y[j][i]**2 < 0.002**2):#(abs(X[0][i]) > 0.001) or (abs(Y[j][i]) > 0.001):#
            Gau_ini[j][i] = 1
        else:
            Gau_ini[j][i] = 0#(1/(w0*np.pi**0.5))*np.exp(-(X[j][i]**2+Y[j][i]**2)/(w0**2))

Energy_init = dx*dx*sum(sum(abs(Gau_ini)**2)) # Energy of initial gaussian beam

Lens = np.exp(1j*k0/(2*f)*(X**2+Y**2)) # Lens eaquation

Gau_ini = Gau_ini*Lens # Gaussian beam trough the lens

H = np.exp(1j/(2*k0)*dz*(KX**2+KY**2)) # Free space transfer function of propagation

Gau = Gau_ini
nl = 0
z = np.arange(0,Z+dz,dz)
Gau_pro = np.zeros((N+1,len(z)),dtype = complex)
for i in z:  # Calculer la propagation du faisceau :
    FGau = np.fft.fft2(Gau)
    FGau = FGau*np.fft.fftshift(H)
    Gau = np.fft.ifft2(FGau)
    Gau_pro[:,nl] = Gau[:,int(N/2)]
    nl += 1

Energy_pro = dx*dx*sum(sum(abs(Gau)**2)) # Vérifier la conservation de l'énergie

x *= 1e3
y *= 1e3
z *= 1e3

# %%
fig,ax = plt.subplots()
im = ax.contourf(x,y,abs(Gau_ini),np.linspace(0,np.amax(abs(Gau_ini)),N),cmap = "jet")
ax.set_xlabel("x (mm)")
ax.set_ylabel("y (mm)")
ax.set_title("Initial beam shape")
fig.colorbar(im, ax=ax)
plt.show()



fig,ax = plt.subplots()
im = ax.contourf(x,y,abs(Gau),np.linspace(0,np.amax(abs(Gau)),N),cmap = "jet")
ax.set_xlabel("x (mm)")
ax.set_ylabel("y (mm)")
ax.set_title("Beam shape at z=15m")
fig.colorbar(im, ax=ax,)
plt.show()


fig,ax = plt.subplots()
A = np.zeros(nl)
for i in range(nl):
    A[i] = 1/max(abs(Gau_pro[:,i]))
B = np.diag(A)
N_Gau_pro = np.dot(abs(Gau_pro),B)
im = ax.contourf(z,x,N_Gau_pro,np.linspace(0,np.amax(abs(N_Gau_pro)),N),cmap = "jet")
ax.set_xlabel("z (mm)")
ax.set_ylabel("x (mm)")
ax.set_title("Beam waist along z")
fig.colorbar(im, ax=ax)
plt.show()

# %% [markdown]
# ## Diffraction pattern for a square hole
# Simulation de la diffraction d'un front d'onde plan passant au travers d'une fente carrée de 0.02mm de largeur. La longueur d'onde centrale est de 0.663$\mu$m et la longueur focale de la lentille est posée à 1e20 mm pour s'assurer qu'elle ait un impact négligeable sur la propagation du faisceau. La simulation est faite sur une distance de 15m avec des incréments à tout les 1m.

# %%
N = 255# Sampling number 
L = 30e-3 # Display area
Ld = 0.663e-6 # Wavelength
k0 = 2*np.pi/Ld # Wave number
w0 = 10e-3 # Initial beam waist
dz = 1000e-3 # deltaz
Z = 15 # final z position
f = 1e20 # Focal length of lens

# %%
dx = L/N # Step size
# Définir les vecteurs x, y, kx et ky (les nombres d'onde dans ces directions) :
x = np.zeros(N+1)
Kx = np.zeros(N+1)
y = np.zeros(N+1)
Ky = np.zeros(N+1)
for m in range(N+1):
    x[m] = (m)*dx-L/2
    Kx[m] = (2*np.pi*(m))/(N*dx)-((2*np.pi*(N-1))/(N*dx))/2
for n in range(N+1):
    y[n] = (n)*dx-L/2
    Ky[n] = (2*np.pi*(n))/(N*dx)-((2*np.pi*(N-1))/(N*dx))/2
    
X,Y = np.meshgrid(x,y)
KX,KY = np.meshgrid(Kx,Ky)
Gau_ini = np.zeros((len(X),len(Y)))
for i in range(len(X)):   # Définir le faisceau comme passant dans une fente :
    for j in range(len(Y)):
        if (abs(X[0][i]) > 0.001) or (abs(Y[j][i]) > 0.001):#
            Gau_ini[j][i] = 0
        else:
            Gau_ini[j][i] = 1#(1/(w0*np.pi**0.5))*np.exp(-(X[j][i]**2+Y[j][i]**2)/(w0**2))

Energy_init = dx*dx*sum(sum(abs(Gau_ini)**2)) # Energy of initial gaussian beam

Lens = np.exp(1j*k0/(2*f)*(X**2+Y**2)) # Lens eaquation

Gau_ini = Gau_ini*Lens # Gaussian beam trough the lens

H = np.exp(1j/(2*k0)*dz*(KX**2+KY**2)) # Free space transfer function of propagation

Gau = Gau_ini
nl = 0
z = np.arange(0,Z+dz,dz)
Gau_pro = np.zeros((N+1,len(z)),dtype = complex)
for i in z:  # Calculer la propagation du faisceau :
    FGau = np.fft.fft2(Gau)
    FGau = FGau*np.fft.fftshift(H)
    Gau = np.fft.ifft2(FGau)
    Gau_pro[:,nl] = Gau[:,int(N/2)]
    nl += 1

Energy_pro = dx*dx*sum(sum(abs(Gau)**2)) # Vérifier la conservation de l'énergie

x *= 1e3
y *= 1e3
z *= 1e3

# %%
fig,ax = plt.subplots()
im = ax.contourf(x,y,abs(Gau_ini),np.linspace(0,np.amax(abs(Gau_ini)),N),cmap = "jet")
ax.set_xlabel("x (mm)")
ax.set_ylabel("y (mm)")
ax.set_title("Initial beam shape")
fig.colorbar(im, ax=ax)
plt.show()


fig,ax = plt.subplots()
im = ax.contourf(x,y,abs(Gau),np.linspace(0,np.amax(abs(Gau)),N),cmap = "jet")
ax.set_xlabel("x (mm)")
ax.set_ylabel("y (mm)")
ax.set_title("Beam shape at z=15m")
fig.colorbar(im, ax=ax,)
plt.show()

fig,ax = plt.subplots()
A = np.zeros(nl)
for i in range(nl):
    A[i] = 1/max(abs(Gau_pro[:,i]))
B = np.diag(A)
N_Gau_pro = np.dot(abs(Gau_pro),B)
im = ax.contourf(z,x,N_Gau_pro,np.linspace(0,np.amax(abs(N_Gau_pro)),N),cmap = "jet")
ax.set_xlabel("z (mm)")
ax.set_ylabel("x (mm)")
ax.set_title("Beam waist along z")
fig.colorbar(im, ax=ax)
plt.show()

# %% [markdown]
# # Propagation of a Gaussian beam through a square-law medium

# %% [markdown]
# Propagation dans un milieu d'indice $n^2 = n_0^2 - n_2(x^2+y^2)$ avec $n_0 = 1.5$ et $n_2 = 0.01$. La simulation est effectuée sur une distance de 85m et est évaluée à tous les 2m pour un faisceau gaussien de largeur initiale de 5mm à une longueur d'onde de 0.633$\mu$m.

# %%
# Reset Jupyter memory
# %reset -f 
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter

# %%
n0 = 1.5 # Refractive index at the center
n2 = 0.01 # Variation of the refractive index
N = 500 # Samplig number
L = 20e-3 # Length of back round
Ld = 0.633e-6/n0  # Wavelength
k0 = 2*np.pi/Ld # Wave number
w0 = 5e-3 # Gaussian beam waist
dz = 2000e-3 # deltaz
Z = 85000e-3 # final z position

# %%
dx = L/N
# Définir les vecteurs x, y, kx et ky (les nombres d'onde dans ces directions) :
x = np.zeros(N+1)
Kx = np.zeros(N+1)
y = np.zeros(N+1)
Ky = np.zeros(N+1)
for m in range(N+1):
    x[m] = (m)*dx-L/2
    Kx[m] = (2*np.pi*(m))/(N*dx)-((2*np.pi*(N))/(N*dx))/2
for n in range(N+1):
    y[n] = (n)*dx-L/2
    Ky[n] = (2*np.pi*(n))/(N*dx)-((2*np.pi*(N))/(N*dx))/2
    
X,Y = np.meshgrid(x,y)
KX,KY = np.meshgrid(Kx,Ky)

Gau_ini = (1/(w0*np.pi**0.5))*np.exp(-(X**2+Y**2)/(w0**2)) # Gaussian beam in space domain

Energy_init = dx*dx*sum(sum(abs(Gau_ini)**2)) # Energy of initial gaussian beam

H = np.exp(1j/(2*k0)*dz*(KX**2+KY**2)) # Free space transfer function of propagation

S = -1j*(-n2/(2*n0**2)*(X**2+Y**2))*k0 # Paramètre d'inhomogénéité

Gau = Gau_ini

nl = 0
z = np.arange(0,Z+dz,dz)
Gau_pro = np.zeros((N+1,len(z)),dtype = complex)
for i in z: # Calculer la propagation du faisceau :
    FGau = np.fft.fft2(Gau)
    FGau = FGau*np.fft.fftshift(H)
    Gau = np.fft.ifft2(FGau)
    Gau *= np.exp(S*dz)
    Gau_pro[:,nl] = Gau[:,int(N/2)]
    nl += 1

Energy_pro = dx*dx*sum(sum(abs(Gau)**2)) # Vérifier la conservation de l'énergie

x *= 1e3
y *= 1e3
z *= 1e3

# %%
fig = plt.figure()
ax = fig.gca(projection='3d')
surf = ax.plot_surface(X, Y, abs(Gau_ini), cmap=cm.jet,
                       linewidth=0, antialiased=False)

# Customize the z axis.
ax.set_xlabel("x (mm)")
ax.set_ylabel('y (mm)')
ax.set_title("Initial Gaussian beam profile")
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))
plt.show()


fig = plt.figure()
ax = fig.gca(projection='3d')
surf = ax.plot_surface(X, Y, abs(Gau), cmap=cm.jet,
                       linewidth=0, antialiased=False)
ax.set_xlabel("x (mm)")
ax.set_ylabel('y (mm)')
ax.set_title("Propagated Gaussian Beam at Z")
ax.zaxis.set_major_locator(LinearLocator(10))
ax.zaxis.set_major_formatter(FormatStrFormatter('%.02f'))
plt.show()


fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
for i in range(nl):
    ax.plot(z[i]*np.ones(len(x)),  abs(Gau_pro[:,i]) ,x, zdir='y')
ax.set_xlabel('z (mm)')
ax.set_ylabel('x (mm)')
ax.set_title("Beam profile along z")
plt.show()



fig,ax = plt.subplots()
A = np.zeros(nl)
for i in range(nl):
    A[i] = 1/max(abs(Gau_pro[:,i]))
B = np.diag(A)
N_Gau_pro = np.dot(abs(Gau_pro),B)
im = ax.contourf(z,x,N_Gau_pro,np.linspace(0,np.amax(abs(N_Gau_pro)),N),cmap = "jet")
ax.set_xlabel("z (mm)")
ax.set_ylabel("x (mm)")
ax.set_title("Beam waist along z")
fig.colorbar(im, ax=ax)
plt.show()


fig, ax = plt.subplots()
for i in range(nl):
    A[i] = max(abs(Gau_pro[:,i]))
ax.plot(z, A/max(A))
ax.set_xlabel("z (mm)")
ax.set_ylabel("Amplitude normalisée [-]")
ax.set_title("Peak amplitude along z")
plt.show()

# %% [markdown]
# # Effet Kerr
# Propagation dans un milieu d'indice $n = n_0 +n_2I$ avec $n_0 = 1.5$ et $n_2 = 2e-13$. La simulation est effectuée sur une distance de 24m et est évaluée à tous les 25mm pour un faisceau gaussien de largeur initiale de 1mm à une longueur d'onde de 0.633$\mu$m.

# %%
# Reset Jupyter memory
# %reset -f 
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
from matplotlib.ticker import LinearLocator, FormatStrFormatter

# %%
n0 = 1.5 # Refractive index 
n2 = 2e-13 # Non linear refractive index
N = 255 # Samplig number
L = 10e-3 # Length of back round
Ld = (0.633/n0)*1e-6 # Wavelength in the material
k0 = (2*np.pi)/Ld # Wave number
w0 = 1e-3 # Gaussian beam waist
dz = 25e-3 # deltaz
Z = 24000e-3 # final z position

# %%
dx = L/N
# Définir les vecteurs x et kx (le nombre d'onde dans cette direction) :
x = np.zeros(N+1)
Kx = np.zeros(N+1)
for m in range(N+1):
    x[m] = (m)*dx-L/2
    Kx[m] = (2*np.pi*(m))/(L)-((np.pi*(N))/(L))

A = 1 # Amplitude factor  # Si A = 1, alors la puissance est assez élevée pour voir apparaître l'autofocalisation
Gau_ini = A*(1/(w0*np.pi**0.5))*np.exp(-(x**2)/(w0**2))  # Gaussian beam in space domain

Energy_ini = dx*sum(abs(Gau_ini)**2) # Energy of initial gaussian beam

H = np.exp(1j/(2*k0)*dz*Kx**2)  # Free space transfer function of propagation

Gau = Gau_ini

nl = 0
z = np.arange(0,Z+dz,dz)
Gau_pro = np.zeros((N+1,len(z)),dtype = complex)
for i in z:  # Calculer la propagation du faisceau :
    FGau = np.fft.fft(Gau)
    FGau = FGau*np.fft.fftshift(H)
    Gau = np.fft.ifft(FGau)
    S = -1j*n2*k0*abs(Gau)**2 # Paramètre d'inhomogénéité
    Gau *= np.exp(S*dz)
    Gau_pro[:,nl] = Gau
    nl += 1

    
Energy_pro = dx*sum(abs(Gau)**2)  # Vérifier la conservation de l'énergie

x *= 1e3
z *= 1e3

# %%
fig, ax = plt.subplots()
ax.plot(x,abs(Gau_ini)/np.amax(abs(Gau_ini)))
ax.set_xlabel("x (mm)")
ax.set_ylabel("Amplitude")
ax.set_title("Initial Beam")
plt.show()

fig, ax = plt.subplots()
ax.plot(x,abs(Gau)/max(abs(Gau)))
ax.set_xlabel("x (mm)")
ax.set_ylabel("Amplitude")
ax.set_title("Propagated Beam")
plt.show()

fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
for i in range(nl):
    ax.plot(z[i]*np.ones(len(x)),  abs(Gau_pro[:,i]) ,x, zdir='y')
ax.set_xlabel('z (mm)')
ax.set_ylabel('x (mm)')
ax.set_title("Beam profile along z")
plt.show()


fig,ax = plt.subplots()
A = np.zeros(nl)
for i in range(nl):
    A[i] = 1/max(abs(Gau_pro[:,i]))
B = np.diag(A)
N_Gau_pro = np.dot(abs(Gau_pro),B)
im = ax.contourf(z,x,N_Gau_pro,np.linspace(0,np.amax(abs(N_Gau_pro)),N),cmap = "jet")
ax.set_xlabel("z (mm)")
ax.set_ylabel("x (mm)")
ax.set_title("Beam waist along z")
fig.colorbar(im, ax=ax)
plt.show()


fig, ax = plt.subplots()
for i in range(nl):
    A[i] = max(abs(Gau_pro[:,i]))
ax.plot(z, A/max(A))
ax.set_xlabel("z (mm)")
ax.set_ylabel("Amplitude normalisée [-]")
ax.set_title("Peak amplitude along z")
plt.show()

# %% [markdown]
# ## Effet Kerr avec variation d'indice négative
#
# On recommence la même simulation, mais $n_2$ est maintenant négatif. On va alors voir de la défocalisation.

# %%
n0 = 1.5 # Refractive index 
n2 = -2e-13 # Non linear refractive index
N = 255 # Samplig number
L = 10e-3 # Length of back round
Ld = (0.633/n0)*1e-6 # Wavelength in the material
k0 = (2*np.pi)/Ld # Wave number
w0 = 1e-3 # Gaussian beam waist
dz = 25e-3 # deltaz
Z = 24000e-3 # final z position

# %%
dx = L/N
# Définir les vecteurs x et kx (le nombre d'onde dans cette direction) :
x = np.zeros(N+1)
Kx = np.zeros(N+1)
for m in range(N+1):
    x[m] = (m)*dx-L/2
    Kx[m] = (2*np.pi*(m))/(L)-((np.pi*(N))/(L))

    
A = 1 # Amplitude factor  # Si A = 1, alors la puissance est assez élevée pour voir apparaître l'autofocalisation
Gau_ini = A*(1/(w0*np.pi**0.5))*np.exp(-(x**2)/(w0**2))   # Gaussian beam in space domain

Energy_ini = dx*sum(abs(Gau_ini)**2) # Energy of initial gaussian beam

H = np.exp(1j/(2*k0)*dz*Kx**2) # Free space transfer function of propagation

Gau = Gau_ini

nl = 0
z = np.arange(0,Z+dz,dz)
Gau_pro = np.zeros((N+1,len(z)),dtype = complex)
for i in z: # Calculer la propagation du faisceau :
    FGau = np.fft.fft(Gau)
    FGau = FGau*np.fft.fftshift(H)
    Gau = np.fft.ifft(FGau)
    S = -1j*n2*k0*abs(Gau)**2 # Paramètre d'inhomogénéité
    Gau *= np.exp(S*dz)
    Gau_pro[:,nl] = Gau
    nl += 1

    
Energy_pro = dx*sum(abs(Gau)**2) # Vérifier la conservation de l'énergie

x *= 1e3
z *= 1e3

# %%
fig, ax = plt.subplots()
ax.plot(x,abs(Gau_ini)/np.amax(abs(Gau_ini)))
ax.set_xlabel("x (mm)")
ax.set_ylabel("Amplitude")
ax.set_title("Initial Beam")
plt.show()

fig, ax = plt.subplots()
ax.plot(x,abs(Gau)/max(abs(Gau)))
ax.set_xlabel("x (mm)")
ax.set_ylabel("Amplitude")
ax.set_title("Propagated Beam")
plt.show()

fig = plt.figure()
ax = fig.add_subplot(111,projection='3d')
for i in range(nl):
    ax.plot(z[i]*np.ones(len(x)),  abs(Gau_pro[:,i]) ,x, zdir='y')
ax.set_xlabel('z (mm)')
ax.set_ylabel('x (mm)')
ax.set_title("Beam profile along z")
plt.show()


fig,ax = plt.subplots()
A = np.zeros(nl)
for i in range(nl):
    A[i] = 1/max(abs(Gau_pro[:,i]))
B = np.diag(A)
N_Gau_pro = np.dot(abs(Gau_pro),B)
im = ax.contourf(z,x,N_Gau_pro,np.linspace(0,np.amax(abs(N_Gau_pro)),N),cmap = "jet")
ax.set_xlabel("z (mm)")
ax.set_ylabel("x (mm)")
ax.set_title("Beam waist along z")
fig.colorbar(im, ax=ax)
plt.show()


fig, ax = plt.subplots()
for i in range(nl):
    A[i] = max(abs(Gau_pro[:,i]))
ax.plot(z, A/max(A))
ax.set_xlabel("z (mm)")
ax.set_ylabel("Amplitude normalisée [-]")
ax.set_title("Peak amplitude along z")
plt.show()
